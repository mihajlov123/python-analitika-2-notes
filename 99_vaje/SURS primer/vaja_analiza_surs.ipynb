# %%
import pandas as pd

regije_zaposlenost = pd.read_csv("./data/Delovno aktivno prebivalstvo po statusu aktivnosti in občinah delovnega mesta Slovenija mesečno.csv",
encoding='ISO-8859-1', skiprows=1,sep=',')
regije_zaposlenost.sample(10)
# Out:
#                  OBÈINE             DELOVNO AKTIVNO PREBIVALSTVO 2005M01  \
# 773  Slovenska Bistrica      120 Samozaposlene osebe brez kmetov     826
# 763              Seana      120 Samozaposlene osebe brez kmetov     409
# 46               Bohinj              11 Zaposlene osebe - SKUPAJ    1147
# 397               Lako          12 Samozaposlene osebe - SKUPAJ     707
# 900  martno pri Litiji  1 Delovno aktivno prebivalstvo - SKUPAJ    1189
# 759             Sevnica         123 Samozaposlene osebe - kmetje     492
# 661                Ptuj              11 Zaposlene osebe - SKUPAJ   11059
# 39                 Bled         123 Samozaposlene osebe - kmetje      93
# 264    Hrpelje - Kozina         123 Samozaposlene osebe - kmetje      70
# 798              Stare      120 Samozaposlene osebe brez kmetov      96
#
#     2005M02 2005M03 2005M04 2005M05 2005M06 2005M07 2005M08  ... 2022M02  \
# 773     829     823     819     816     816     812     812  ...     844
# ...

# %%
mesecne_place = pd.read_csv("./data/mesecne_place_po_dejavnostih.csv", encoding='ISO-8859-1', skiprows=1,sep=' ')
mesecne_place.sample(10)

# %%
place_izobrazba = pd.read_csv("./data/povprecne_place_dejavnost_izobrazba.csv", encoding='ISO-8859-1', skiprows=1,sep=',')
place_izobrazba.sample(10)

# %%
denarna_sredstva = pd.read_csv("./data/povprecno porabljena denarna sredstav gospodinjstev.csv", encoding='ISO-8859-1', skiprows=1,sep=',')
denarna_sredstva.head()
