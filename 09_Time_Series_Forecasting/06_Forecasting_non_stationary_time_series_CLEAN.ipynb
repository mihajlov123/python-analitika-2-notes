# %% [markdown]
# # Forecasting non-stationary time series

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.graphics.gofplots import qqplot
from statsmodels.tsa.stattools import adfuller
from tqdm.notebook import tqdm
from itertools import product
from typing import Union

# %% [markdown]
# Now we’ll **add another component to the `ARMA(p,q)` model so we can forecast
# non-stationary time series.**
# - do sedaj smo napovedovali tako, da smo naredili transformacijo z diff v stacionarno vrsto in nato na koncu naredili inverzno transformacijo
# - lahko uporabimo ARIMA(p,d,q) modele, ki ima že vgrajen integracijski del in ni potrebno transformirati v stacionarno vrsto
# - d pomeni stopnjo integracije -> kolikokrat je potrebno diferencirati, da je vrsta stacionarna

# %% [markdown]
# ## Defining the autoregressive integrated moving average model

# %% [markdown]
# **An autoregressive integrated moving average (ARIMA) process is the combination of
# the AR(p) and MA(q) processes, but in terms of the differenced series.**

# %% [markdown]
# ## Modifying the general modeling procedure to account for non-stationary series

# %% [markdown]
# <img src="images/tsf_07.png">

# %% [markdown]
# ## Forecasting a non-stationary times series
# - določimo d -> kolikokrat diferenciramo da pridemo do stacionarne vrste
# - preostali postopek je enak kot v poglavju 05_Modeling_complex_time_series
#     - q-q plot
#     - uncorelated residuals

# %%
df = pd.read_csv('data/jj.csv')
df.head()
# Out:
#          date  data
# 0  1960-01-01  0.71
# 1  1960-04-01  0.63
# 2  1960-07-02  0.85
# 3  1960-10-01  0.44
# 4  1961-01-01  0.61

# %%
fig, ax = plt.subplots()

ax.plot(df.date, df['data'])
ax.set_xlabel('Date')
ax.set_ylabel('Earnings per share (USD)')

plt.xticks(np.arange(0, 81, 8), [1960, 1962, 1964, 1966, 1968, 1970, 1972, 1974, 1976, 1978, 1980])

fig.autofmt_xdate()
plt.tight_layout()

# %%
ad_fuller_result = adfuller(df['data'])

print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: 2.742016573457468
# p-value: 1.0

# %%
eps_diff = np.diff(df['data'], n=1)

ad_fuller_result = adfuller(eps_diff)

print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -0.40740976363803433
# p-value: 0.9088542416911325

# %%
eps_diff2 = np.diff(eps_diff, n=1)

ad_fuller_result = adfuller(eps_diff2)

print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -3.585162874793174
# p-value: 0.006051099869603299

# %%
fig, ax = plt.subplots()

ax.plot(df['date'][2:], eps_diff2)
ax.set_xlabel('Date')
ax.set_ylabel('Earnings per share - diff (USD)')

plt.xticks(np.arange(0, 81, 8), [1960, 1962, 1964, 1966, 1968, 1970, 1972, 1974, 1976, 1978, 1980])

fig.autofmt_xdate()
plt.tight_layout()

# %%
fig, ax = plt.subplots()

ax.plot(df.date, df.data)
ax.set_xlabel('Date')
ax.set_ylabel('Earnings per share (USD)')
ax.axvspan(80, 83, color='#808080', alpha=0.2)

plt.xticks(np.arange(0, 81, 8), [1960, 1962, 1964, 1966, 1968, 1970, 1972, 1974, 1976, 1978, 1980])

fig.autofmt_xdate()
plt.tight_layout()

# %%
def optimize_ARIMA(endog: Union[pd.Series, list], order_list: list, d: int) -> pd.DataFrame:
    
    results = []
    
    for order in tqdm(order_list):
        try: 
            model = SARIMAX(endog, order=(order[0], d, order[1]), simple_differencing=False).fit(disp=False)
        except:
            continue
            
        aic = model.aic
        results.append([order, aic])
        
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q)', 'AIC']
    
    #Sort in ascending order, lower AIC is better
    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)
    
    return result_df

# %%
ps = range(0, 4, 1)
qs = range(0, 4, 1)
d = 2

order_list = list(product(ps, qs))

# %%
train = df['data'][:-4]

result_df = optimize_ARIMA(train, order_list, d)
result_df
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#      (p,q)         AIC
# 0   (3, 3)  115.270754
# 1   (3, 1)  115.624981
# 2   (3, 2)  115.672007
# 3   (3, 0)  154.430621
# 4   (0, 3)  194.654716
# 5   (0, 2)  209.274544
# 6   (2, 3)  220.666893
# 7   (1, 3)  228.267654
# 8   (1, 2)  228.935827
# 9   (2, 2)  229.974712
# 10  (2, 1)  234.501112
# 11  (1, 1)  236.117331
# 12  (0, 1)  252.601135
# 13  (2, 0)  280.299907
# 14  (1, 0)  280.389386
# 15  (0, 0)  320.324435

# %% [markdown]
# V nadaljevanju vidimo, da model ni več najbolj idealen. Iz Correlograma so določeni lagi že malo večji. Vrednosti residualov pa so nekateri že malo manjšega reda. Nadaljujemo z uporabo tega modela -> v nbadaljevanju pa bomo vpeljali še sezonskost (SARIMA modele)

# %%
model = SARIMAX(train, order=(3,2,3), simple_differencing=False)
model_fit = model.fit(disp=False)
model_fit.plot_diagnostics(figsize=(10,8));
plt.show()
# Out:
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Local_documents\Coding projects\python-analitika-2-notes\.venv\Lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
residuals = model_fit.resid

res = acorr_ljungbox(residuals, np.arange(1, 11, 1))

print(list(res["lb_pvalue"]))
# Out:
# [0.192034575835977, 0.4262927114187498, 0.06325007651333195, 0.05509708814965191, 0.07874363569968736, 0.11990204483359988, 0.1688896120552619, 0.23835797866135003, 0.2943128764138251, 0.34412041555438905]

# %%
test = df.iloc[-4:]

test['naive_seasonal'] = df['data'].iloc[76:80].values
test
# Out:
# C:\Users\matic.zirovec\AppData\Local\Temp\ipykernel_16124\3007513500.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['naive_seasonal'] = df['data'].iloc[76:80].values
#           date   data  naive_seasonal
# 80  1980-01-01  16.20           14.04
# 81  1980-04-01  14.67           12.96
# 82  1980-07-02  16.02           14.85
# 83  1980-10-01  11.61            9.99

# %%
ARIMA_pred = model_fit.get_prediction(80, 83).predicted_mean

test['ARIMA_pred'] = ARIMA_pred
test
# Out:
# C:\Users\matic.zirovec\AppData\Local\Temp\ipykernel_16124\1028357784.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['ARIMA_pred'] = ARIMA_pred
#           date   data  naive_seasonal  ARIMA_pred
# 80  1980-01-01  16.20           14.04   15.855244
# 81  1980-04-01  14.67           12.96   14.378400
# 82  1980-07-02  16.02           14.85   16.369348
# 83  1980-10-01  11.61            9.99   11.678458

# %%
fig, ax = plt.subplots()

ax.plot(df['date'], df['data'])
ax.plot(test['data'], 'b-', label='actual')
ax.plot(test['naive_seasonal'], 'r:', label='naive seasonal')
ax.plot(test['ARIMA_pred'], 'k--', label='ARIMA(3,2,3)')

ax.set_xlabel('Date')
ax.set_ylabel('Earnings per share (USD)')
ax.axvspan(80, 83, color='#808080', alpha=0.2)

ax.legend(loc=2)

plt.xticks(np.arange(0, 81, 8), [1960, 1962, 1964, 1966, 1968, 1970, 1972, 1974, 1976, 1978, 1980])
ax.set_xlim(60, 83)

fig.autofmt_xdate()
plt.tight_layout()

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mape_naive_seasonal = mape(test['data'], test['naive_seasonal'])
mape_ARIMA = mape(test['data'], test['ARIMA_pred'])

print(mape_naive_seasonal, mape_ARIMA)
# Out:
# 11.561658552433654 1.7215490973249443

# %%
fig, ax = plt.subplots()

x = ['naive seasonal', 'ARIMA(3,2,3)']
y = [mape_naive_seasonal, mape_ARIMA]

ax.bar(x, y, width=0.4)
ax.set_xlabel('Models')
ax.set_ylabel('MAPE (%)')
ax.set_ylim(0, 15)

for index, value in enumerate(y):
    plt.text(x=index, y=value + 1, s=str(round(value,2)), ha='center')

plt.tight_layout()

# %% [markdown]
# ## Summary

# %% [markdown]
# - The autoregressive integrated moving average model, denoted as ARIMA(p,d,q),
# is the combination of the autoregressive model AR(p), the order of integration
# d, and the moving average model MA(q).
# - The ARIMA(p,d,q) model can be applied on non-stationary time series and
# has the added advantage of returning forecasts in the same scale as the original
# series.
# - The order of integration d is equal to the minimum number of times a series
# must be differenced to become stationary.
# - An ARIMA(p,0,q) model is equivalent to an ARMA(p,q) model.
